# %%
# 값을 여러개 출력하기
print(1, 2, 3)
print("Hello", "Python")
# Out:
# 1 2 3
# HelloPython

# %%
#  sep로 값 사이에 문자 넣기
print(1, 2, 3, sep = '')
print(4, 5, 6, sep = ',')
print(1920, 1000, sep = " X ")
# Out:
# 123
# 4,5,6
# 1920 X 1000
