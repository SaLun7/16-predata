# %%
# if 조건문 사용하기

x = 10

if x == 10:
    print("10입니다.")
# Out:
# 10입니다.

# %%
# if 조건문에서 코드를 생략하기

x = 10

if x == 10:
    pass

# %%
# if 조건문과 들여쓰기

x = 10

if x == 10:
    print("x에 들어가는 숫자는")
        print("10입니다.")
# Out:
#   Cell In[3], line 7
#     print("10입니다.")
#     ^
# IndentationError: unexpected indent

# %%
x = 10

if x == 10:
    print("x에 들어가는 숫자는")

print("10입니다.")
# Out:
# x에 들어가는 숫자는
# 10입니다.

# %%
# 중첩 if조건문

x = 15

if x > 10:
    print("10이상입니다.")

    if x == 15:
        print("15 입니다.")

    if x == 20:
        print("20 입니다.")
# Out:
# 10이상입니다.
# 15 입니다.

# %%
x = int(input())

if x == 10:
    print("10 입니다.")

if x == 20:
    print("20 입니다.")

# %%
a = int(input())
b = input()

if b == "Cash3000":
    a -= 3000
    print(a)

if b == "Cash5000":
    a -= 5000
    print(a)
# Out:
# 67000
