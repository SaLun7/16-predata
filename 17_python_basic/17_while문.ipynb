# %%
# while 반복문 사용하기

# 초기식
# while 조건식:
#     반복할 코드
#     변화식

i = 0

while i < 10:
    print("hello world")
    i += 1
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world

# %%
for _ in range(10):
    print("hello world")
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world

# %%
# 초깃값을 1부터 시작하기

i = 1
while i <= 10:
    print("hello world", i)
    i += 1
# Out:
# hello world 1
# hello world 2
# hello world 3
# hello world 4
# hello world 5
# hello world 6
# hello world 7
# hello world 8
# hello world 9
# hello world 10

# %%
i = 10
while i > 0:
    print("hello world", i)
    i -= 1
# Out:
# hello world 10
# hello world 9
# hello world 8
# hello world 7
# hello world 6
# hello world 5
# hello world 4
# hello world 3
# hello world 2
# hello world 1

# %%
# 입력한 횟수대로 반복하기

count = int(input("반복할 횟수 입력 : "))

i = 0
while i < count:
    print("hello world", i)
    i += 1
# Out:
# hello world 0
# hello world 1
# hello world 2

# %%
# 반복 횟수가 정해지지 않은 경우

import random

print(random.random())
print(int(random.random() * 100))
# Out:
# 0.9846330537831572
# 32

# %%
print(random.randint(1, 6))
# Out:
# 6

# %%
import random

i = 0
while i != 3:
    i = random.randint(1, 6)
    print(i)
# Out:
# 2
# 5
# 3

# %%
i = 2
j = 5

while i <= 33 or j >= 1:
    print(i, j)
    i *= 2
    j -= 1
# Out:
# 2 5
# 4 4
# 8 3
# 16 2
# 32 1
# 64 0

# %%
a = int(input())

while a >= 0:
    print(a)
    a -= 1350
# Out:
# 10000
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550
